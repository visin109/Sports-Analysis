# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("deliveries.csv")
#df=df[df['batsman']=="V Kohli"]
# columns=["batsman","bowler","player_dismissed","dismissal_kind","batsman_runs"]
# df=df[df["bowler"]=="SK Warne"]
# df=df[df["dismissal_kind"]=="caught"]
# df=df[df["dismissal_kind"]=="caught and bowled"].count()
plt.figure(figsize=(40,40))
# df["dismiss"]=0
# df["player_dismissed"]=df["player_dismissed"].fillna(0)
# if (df[df["player_dismissed"]!=0]):crickt
#     print(True)
# if (df["player_dismissed"].isnull()).all():
#     df["dismiss"]=0
# else:
#     df["dismiss"]=1
# df=df[df["dismiss"]==1]
# df=df[df["bowler"]=="TG Southee"]
# values=df["player_dismissed"].count()
# values
# out=df[df["player_dismissed"]=="Harbhajan Singh"]
# out.count()
# sns.countplot("bowler","")
# columns=["wide_runs","bye_runs","legbye_runs","noball_runs","penalty_runs","extra_runs"]
# df["player_dismissed"]=df["player_dismissed"].fillna(0)
df.head(12)
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 0          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# ...

# %%
df1=pd.read_csv("matches.csv")
perform08=df1[df1["season"]==2008]
winners08=perform08["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2008")
winners08
plt.figure(figsize=(20,10))
# plt.bar(winners08.keys(),winners08.values,color="maroon")
df1[df1["season"]==2018]
df1[df1["winner"]=="Chennai Super Kings"]

# count=pd.isnull(df1["umpire3"])
# count
# Out:
# no of matches won by each team in 2008
#         id  season           city        date                  team1  \
# 60      61    2008     Chandigarh  2008-04-19    Chennai Super Kings
# 66      67    2008        Chennai  2008-04-23    Chennai Super Kings
# 70      71    2008        Chennai  2008-04-26  Kolkata Knight Riders
# 73      74    2008      Bangalore  2008-04-28    Chennai Super Kings
# 86      87    2008          Delhi  2008-05-08       Delhi Daredevils
# ..     ...     ...            ...         ...                    ...
# 720  11316    2019         Jaipur    11/04/19       Rajasthan Royals
# 724  11320    2019        Kolkata    14/04/19  Kolkata Knight Riders
# 736  11332    2019        Chennai    23/04/19    Sunrisers Hyderabad
# 745  11341    2019        Chennai    01/05/19    Chennai Super Kings
# 754  11414    2019  Visakhapatnam    10/05/19         Delhi Capitals
#
#                            team2            toss_winner toss_decision  result  \
# ...

# %%
df2=df.rename({"match_id":"id"}, axis=1)
# df2=df2[df2["season"]=="2008"]
# df2=df2[df2["bowler"]=="SK Warne"]
# deli=df2[df2["bowler"]=="SK Warne"].count()
# count=df2["player_dismissed"].count()
# eco=deli/count'
# runs=df2["batsman_runs"].sum()

# over=df2["over"].count()
# df2["dismissal_kind"]=df2["dismissal_kind"].fillna(0)
# dict1={'caught':0,'bowled':0,'caught and bowled':0,"lbw":0,'run out':0}
# for i in df2["dismissal_kind"]:
#     if i not in dict1.keys():
#         dict1[i]=1
#     else:
#         dict1[i]+=1
        
# print(dict1)
# plt.bar(dict1.keys(),dict1.values)
# runs
df2
# Out:
#            id  inning         batting_team                 bowling_team  over  \
# 0           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# ...       ...     ...                  ...                          ...   ...
# 179073  11415       2  Chennai Super Kings               Mumbai Indians    20
# 179074  11415       2  Chennai Super Kings               Mumbai Indians    20
# 179075  11415       2  Chennai Super Kings               Mumbai Indians    20
# 179076  11415       2  Chennai Super Kings               Mumbai Indians    20
# 179077  11415       2  Chennai Super Kings               Mumbai Indians    20
#
# ...

# %%
ipl=pd.merge(df1,df2,on="id")
# runs=ipl["batsman_runs"].sum()
# ipl=ipl[ipl["season"]==2008]
# runs=ipl["batsman_runs"].sum()
# balls=ipl["ball"].count()
# runs
# ipl=ipl[ipl["season"]==2018]
# rcb=ipl[ipl["batting_team"]=="Royal Challengers Bangalore"]
# rcb=rcb[rcb["batsman"]=="V Kohli"]
# columns=["batsman_runs","ball"]
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
ipl_08=ipl[ipl['season']==2008]
ipl_09=ipl[ipl['season']==2009]
ipl_10=ipl[ipl['season']==2010]
ipl_11=ipl[ipl['season']==2011]
ipl_12=ipl[ipl['season']==2012]
ipl_13=ipl[ipl['season']==2013]
ipl_14=ipl[ipl['season']==2014]
ipl_15=ipl[ipl['season']==2015]
ipl_16=ipl[ipl['season']==2016]
ipl_17=ipl[ipl['season']==2017]
ipl_18=ipl[ipl['season']==2018]
ipl_19=ipl[ipl['season']==2019]
# ipl_08[ipl_08["batsman"]=="V Kohli"]
# ipl_08["season"]=ipl_08["season"].fillna(2008)
# count=ipl_08[ipl_08["season"]==np.nan]
# count
# total_null=ipl_17.isnull().sum()
# percent=total_null/ipl_17.isnull().count()
# percent
# print("No of wickets taken by shane warne in ipl 2008")
# overs=warne["over"].count()
ipl_19
# Out:
#            id  season       city      date                        team1  \
# 164750  11137    2019    Chennai  23/03/19  Royal Challengers Bangalore
# 164751  11137    2019    Chennai  23/03/19  Royal Challengers Bangalore
# 164752  11137    2019    Chennai  23/03/19  Royal Challengers Bangalore
# 164753  11137    2019    Chennai  23/03/19  Royal Challengers Bangalore
# 164754  11137    2019    Chennai  23/03/19  Royal Challengers Bangalore
# ...       ...     ...        ...       ...                          ...
# 179073  11415    2019  Hyderabad  12/05/19               Mumbai Indians
# 179074  11415    2019  Hyderabad  12/05/19               Mumbai Indians
# 179075  11415    2019  Hyderabad  12/05/19               Mumbai Indians
# 179076  11415    2019  Hyderabad  12/05/19               Mumbai Indians
# 179077  11415    2019  Hyderabad  12/05/19               Mumbai Indians
#
#                       team2          toss_winner toss_decision  result  \
# ...

# %%
batsman=set(df["batsman"])
dict2={}
for i in df["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=df[df["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict={}
for i in df["batsman"]:
    if i in batsman:
        dict[i]=0
for i in dict:
    batter=df[df["batsman"]==i]
    balls_faced=batter["batsman_runs"].count()
    dict[i]=balls_faced

d={"batsman":dict2.keys(),"total runs":dict2.values()}
batter_df=pd.DataFrame(d)
batter_df=batter_df.sort_values(by="total runs",ascending=False)
batter_df.head(20)
batter_df=batter_df.rename(columns={'total runs':'total_runs'})
#dict2[i]=runs
#dict2
#batter_df["sixes"]=six
#batter_df

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation=90)
sns.barplot(x='batsman',y='total_runs',data=batter_df.head(20))
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='total_runs'>

# %%
# STRIKE RATES OF THE WINNING CAPTAIN 2008
batsman=set(ipl_08["batsman"])
dict2={}
for i in ipl_08["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_08[ipl_08["batsman"]==i] 
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs

dict3={}
for i in ipl_08["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_08[ipl_08["batsman"]==i]
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values()}
batter_ipl_08=pd.DataFrame(d)
batter_ipl_08=batter_ipl_08.sort_values(by="total runs",ascending=False)
print("Top 5 players with most runs in 2008")
batter_ipl_08=batter_ipl_08.head(5)
batter_ipl_08=batter_ipl_08.set_index(batter_ipl_08["batsman"])
batter_ipl_08
# batter_ipl_08=batter_ipl_08.sort_values(by="total runs",ascending=False)
# STRIKE RATE OF THE WINNING CAPTAIN 2009



# STRIKE RATE OF THE WINNING CAPTAIN 2012

# STRIKE RATE OF THE WINNING CAPTAIN 2015
# Out:
# Top 5 players with most runs in 2008
#                      batsman  total runs  balls_faced
# batsman
# SE Marsh            SE Marsh         616          452
# G Gambhir          G Gambhir         534          394
# ST Jayasuriya  ST Jayasuriya         514          333
# SR Watson          SR Watson         472          322
# GC Smith            GC Smith         441          375

# %%
# import matplotlib
# matplotlib.rc_file_defaults()
# ax1 = sns.set_style(style=None, rc=None )
# fig, ax1= plt.subplots(figsize=(12,6))
# scatter=sns.scatterplot(data=batter_ipl_08["balls_faced"],marker='o')
# ax2=scatter.twinx()
plt.figure(figsize=(10,10))
batter_ipl_08["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_08["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_08, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# sns.lineplot(data=batter_ipl_08["balls_faced"],marker='o', sort = False, ax=ax1)
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
batsman=set(ipl_09["batsman"])
dict2={}
for i in ipl_09["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_09[ipl_09["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict3={}
for i in ipl_09["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_09[ipl_09["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values()}
dict3={}
batter_ipl_09=pd.DataFrame(d)
batter_ipl_09=batter_ipl_09.sort_values(by="total runs",ascending=False)
print("Top 5 players with most runs in 2009")
batter_ipl_09=batter_ipl_09.set_index(batter_ipl_09["batsman"]).head(5)
batter_ipl_09
# Out:
# Top 5 players with most runs in 2009
#                        batsman  total runs  balls_faced
# batsman
# ML Hayden            ML Hayden         572          409
# AC Gilchrist      AC Gilchrist         495          337
# AB de Villiers  AB de Villiers         465          359
# SK Raina              SK Raina         434          318
# TM Dilshan          TM Dilshan         418          357

# %%
plt.figure(figsize=(10,10))
batter_ipl_09["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_09["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_09, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
batsman=set(ipl_10["batsman"])
dict2={}
for i in ipl_10["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_10[ipl_10["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict3={}
for i in ipl_10["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_10[ipl_10["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced
    
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values()}
batter_ipl_10=pd.DataFrame(d)
batter_ipl_10=batter_ipl_10.sort_values(by="total runs",ascending=False)
print("Top 5 players with most runs in 2010")
print(batter_ipl_10.head(5))
# Out:
# Top 5 players with most runs in 2010
#          batsman  total runs  balls_faced
# 16  SR Tendulkar         618          489
# 49     JH Kallis         572          517
# 60      SK Raina         528          387
# 1     SC Ganguly         493          440
# 58       M Vijay         458          305

# %%
batter_ipl_10=batter_ipl_10.set_index(batter_ipl_10["batsman"]).head(5)
plt.figure(figsize=(15,10))
batter_ipl_10["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_10["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_10, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
batsman=set(ipl_11["batsman"])
dict2={}
for i in ipl_11["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_11[ipl_11["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict3={}
for i in ipl_11["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_11[ipl_11["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values()}
batter_ipl_11=pd.DataFrame(d)
batter_ipl_11=batter_ipl_11.sort_values(by="total runs",ascending=False)
print("Top 5 players with most runs in 2011")
print(batter_ipl_11.head(5))
# Out:
# Top 5 players with most runs in 2011
#           batsman  total runs  balls_faced
# 122      CH Gayle         608          342
# 38        V Kohli         557          473
# 54   SR Tendulkar         553          511
# 58       SE Marsh         504          349
# 89     MEK Hussey         492          423

# %%
batter_ipl_11=batter_ipl_11.set_index(batter_ipl_11["batsman"]).head(5)
plt.figure(figsize=(15,10))
batter_ipl_11["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_11["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_11, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
batsman=set(ipl_12["batsman"])
dict2={}
for i in ipl_12["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_12[ipl_12["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict3={}
for i in ipl_12["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_12[ipl_12["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values()}
batter_ipl_12=pd.DataFrame(d)
batter_ipl_12=batter_ipl_12.sort_values(by="total runs",ascending=False)
print("Top 5 players with most runs in 2012")
print(batter_ipl_12.head(5))
# STRIKE RATE OF THE WINNING CAPTAIN 2013
# Out:
# Top 5 players with most runs in 2012
#       batsman  total runs  balls_faced
# 98   CH Gayle         733          472
# 18  G Gambhir         590          429
# 78   S Dhawan         569          448
# 47  AM Rahane         560          448
# 27   V Sehwag         495          317

# %%
batter_ipl_12=batter_ipl_12.set_index(batter_ipl_12["batsman"]).head(5)
plt.figure(figsize=(15,10))
batter_ipl_12["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_12["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_12, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
batsman=set(ipl_13["batsman"])
dict2={}
for i in ipl_13["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_13[ipl_13["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict3={}
dict4={}
for i in ipl_13["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_13[ipl_13["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    strike_rate=(runs/balls_faced)*100
    dict3[i]=balls_faced
    dict4[i]=strike_rate
for i in ipl_13["batsman"]:
    if i in batsman:
        dict4[i]=0
for i in dict4:
    batter=ipl_13[ipl_13["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    strike_rate=(runs/balls_faced)*100
#     dict3[i]=balls_faced
    dict4[i]=strike_rate
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values(),"strike_rate":dict4.values()}
batter_ipl_13=pd.DataFrame(d)
batter_ipl_13=batter_ipl_13.sort_values(by="strike_rate",ascending=False)
print("Top 5 players with most runs in 2013")
# batter_ipl_13[batter_ipl_13["batsman"]=="MS Dhoni"]
batter_ipl_13=batter_ipl_13.sort_values(by="total runs",ascending=False).head(5)
batter_ipl_13
# Out:
# Top 5 players with most runs in 2013
#        batsman  total runs  balls_faced  strike_rate
# 58  MEK Hussey         733          580   126.379310
# 16    CH Gayle         720          484   148.760331
# 18     V Kohli         639          471   135.668790
# 60    SK Raina         548          370   148.108108
# 78   SR Watson         543          393   138.167939

# %%
batter_ipl_13=batter_ipl_13.set_index(batter_ipl_13["batsman"]).head(5)
plt.figure(figsize=(15,10))
batter_ipl_13["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_13["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_13, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
# STRIKE RATE OF THE WINNING CAPTAIN 2014
batsman=set(ipl_14["batsman"])
dict2={}
for i in ipl_14["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_14[ipl_14["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict3={}
for i in ipl_14["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_14[ipl_14["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values()}
batter_ipl_14=pd.DataFrame(d)
batter_ipl_14=batter_ipl_14.sort_values(by="total runs",ascending=False)
print("Top 5 players with most runs in 2014")
print(batter_ipl_14.head(5))
# Out:
# Top 5 players with most runs in 2014
#        batsman  total runs  balls_faced
# 3   RV Uthappa         660          485
# 25    DR Smith         566          425
# 32  GJ Maxwell         552          312
# 37   DA Warner         528          386
# 27    SK Raina         523          370

# %%
batter_ipl_14=batter_ipl_14.set_index(batter_ipl_14["batsman"]).head(5)
plt.figure(figsize=(14,10))
batter_ipl_14["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_14["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_14, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
batsman=set(ipl_15["batsman"])
dict2={}
for i in ipl_15["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_15[ipl_15["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict3={}
for i in ipl_15["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_15[ipl_15["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values()}
batter_ipl_15=pd.DataFrame(d)
batter_ipl_15=batter_ipl_15.sort_values(by="total runs",ascending=False)
print("Top 5 players with most runs in 2015")
print(batter_ipl_15.head(5))
# STRIKE RATE OF THE WINNING CAPTAIN 2017
# Out:
# Top 5 players with most runs in 2015
#            batsman  total runs  balls_faced
# 47       DA Warner         562          368
# 82     LMP Simmons         540          455
# 29       AM Rahane         540          423
# 61  AB de Villiers         513          302
# 58         V Kohli         505          395

# %%
batter_ipl_15=batter_ipl_15.set_index(batter_ipl_15["batsman"]).head(5)
plt.figure(figsize=(15,15))
batter_ipl_15["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_15["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_15, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
batsman=set(ipl_16["batsman"])
dict2={}
for i in ipl_16["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_16[ipl_16["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict3={}
for i in ipl_16["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_16[ipl_16["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values()}
batter_ipl_16=pd.DataFrame(d)
batter_ipl_16=batter_ipl_16.sort_values(by="total runs",ascending=False)
print("Top 5 players with most runs in 2016")
print(batter_ipl_16.head(5))
# Out:
# Top 5 players with most runs in 2016
#            batsman  total runs  balls_faced
# 42         V Kohli         973          655
# 47       DA Warner         848          579
# 43  AB de Villiers         687          415
# 25       G Gambhir         501          424
# 48        S Dhawan         501          438

# %%
batter_ipl_16=batter_ipl_16.set_index(batter_ipl_16["batsman"]).head(5)
plt.figure(figsize=(15,16))
batter_ipl_16["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_16["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_16, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
batsman=set(ipl_17["batsman"])
dict2={}
for i in ipl_17["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_17[ipl_17["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict3={}
for i in ipl_17["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict3:
    batter=ipl_17[ipl_17["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values()}
batter_ipl_17=pd.DataFrame(d)
batter_ipl_17=batter_ipl_17.sort_values(by="total runs",ascending=False)
print("Top 5 players with most runs in 2017")
print(batter_ipl_17.head(5))
# Out:
# Top 5 players with most runs in 2017
#       batsman  total runs  balls_faced
# 0   DA Warner         641          462
# 36  G Gambhir         498          405
# 1    S Dhawan         479          383
# 28  SPD Smith         472          400
# 33   SK Raina         442          310

# %%
batter_ipl_17=batter_ipl_17.set_index(batter_ipl_17["batsman"]).head(5)
plt.figure(figsize=(15,17))
batter_ipl_17.plot(kind='bar',alpha=0.6)
# sns.scatterplot(data=batter_ipl_17["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
# sns.lineplot(data=batter_ipl_17, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")

# sns.barplot(data=batter_ipl_17,x="total_runs",y="")
# Out:
# <AxesSubplot:xlabel='batsman'>

# %%
# STRIKE RATE OF THE WINNING CAPTAIN 2018\
batsman=set(ipl_18["batsman"])
dict2={}
for i in ipl_18["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_18[ipl_18["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
dict3={}
for i in ipl_18["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_18[ipl_18["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced

d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values()}
batter_ipl_18=pd.DataFrame(d)
batter_ipl_18=batter_ipl_18.sort_values(by="total runs",ascending=False)
print("Top 5 players with most runs in 2018")
batter_ipl_18.head(5)
# Out:
# Top 5 players with most runs in 2018
#           batsman  total runs  balls_faced
# 59  KS Williamson         747          522
# 21        RR Pant         717          412
# 25       KL Rahul         678          426
# 7       AT Rayudu         615          410
# 51     JC Buttler         574          365

# %%
batter_ipl_18=batter_ipl_18.set_index(batter_ipl_18["batsman"]).head(5)
plt.figure(figsize=(15,15))
batter_ipl_18["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_18["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_18, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
# STRIKE RATE OF THE WINNING CAPTAIN 2019
batsman=set(ipl_19["batsman"])
dict2={}
for i in ipl_19["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=ipl_19[ipl_19["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    batsman_runs=batter['batsman_runs'].sum()
    balls_faced=batter['ball'].count()
    dict2[i]=batsman_runs
dict3={}
dict4={}
for i in ipl_19["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict2:
    batter=ipl_19[ipl_19["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter['ball'].count()
    dict3[i]=balls_faced
    strike_rate=(runs/balls_faced)*100
    dict4[i]=strike_rate
d={"batsman":dict2.keys(),"total runs":dict2.values(),"balls_faced":dict3.values(),"strike_rate":dict4.values()}
batter_ipl_19=pd.DataFrame(d)
print("Top 5 players with most runs in 2019")
batter_ipl_19=batter_ipl_19.sort_values(by="total runs",ascending=False)
# batter_ipl_18
print(batter_ipl_19.head(5))
# Out:
# Top 5 players with most runs in 2019
#        batsman  total runs  balls_faced  strike_rate
# 16   DA Warner         727          496   146.572581
# 45    KL Rahul         610          447   136.465324
# 36   Q de Kock         555          406   136.699507
# 25  AD Russell         545          274   198.905109
# 28    S Dhawan         542          392   138.265306

# %%
batter_ipl_19=batter_ipl_19.set_index(batter_ipl_19["batsman"]).head(5)
plt.figure(figsize=(15,19))
batter_ipl_19["total runs"].plot(kind='bar',color="blue",alpha=0.6)
sns.scatterplot(data=batter_ipl_19["balls_faced"],marker='o',color="black",palette="deep",label="number of balls faced")
sns.lineplot(data=batter_ipl_19, x='batsman', y='balls_faced',estimator='max', color='red',label="trend of balls faced")
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='balls_faced'>

# %%
batsman=set(df["batsman"])
ids=set(ipl["id"])
dict3={}
dict4={}
columns=["id","batsman","batsman_runs"]
ipl_19=ipl_19[columns]
for i in ipl_19["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in ipl_19["id"]:
    if i in ids:
        dict4[i]=0
dict4={}
for i in dict3:
    batter=ipl_19[ipl_19["batsman"]==i]
#     for j in dict4.keys():
#         j=str(j)
    runs=batter.groupby(["id","batsman"],as_index=False).agg({"batsman_runs":"sum"})
#     batsman=runs[runs]
#     print(runs)
    fifty=runs[(runs['batsman_runs']>=50) & (runs['batsman_runs']<100)].count()
#     columns=["batsman","batsman_runs"]
    for i in runs["batsman"]:
        if i in dict3.keys():
            dict3[i]=fifty["batsman_runs"]
dict3
d={"batsman":dict3.keys(),"number of fifties 2019":dict3.values()}
fifties_19=pd.DataFrame(d)
fifties_19.sort_values(by="number of fifties 2019",ascending=False)
# Out:
#             batsman  number of fifties 2019
# 16        DA Warner                       8
# 25       AD Russell                       6
# 45         KL Rahul                       6
# 28         S Dhawan                       5
# 3    AB de Villiers                       5
# ..              ...                     ...
# 70           N Naik                       0
# 69      Rashid Khan                       0
# 67        JJ Bumrah                       0
# 66       M Markande                       0
# 143        I Sharma                       0
#
# [144 rows x 2 columns]

# %%
batsman=set(df["batsman"])
ids=set(ipl["id"])
dict3={}
dict4={}
columns=["id","batsman","batsman_runs"]
ipl_19=ipl_19[columns]
for i in ipl_19["batsman"]:
    if i in batsman:
        dict3[i]=0
# for i in ipl_19["id"]:
#     if i in ids:
#         dict4[i]=0
dict4={}
for i in dict3:
    batter=ipl_19[ipl_19["batsman"]==i]
    runs=batter.groupby(["id","batsman"],as_index=False).agg({"batsman_runs":"sum"})
    maximum=runs.groupby(["batsman"],as_index=False).agg({"batsman_runs":'max'})
    fifty=runs[(runs['batsman_runs']>=100)].count()
    for i in runs["batsman"]:
        if i in dict3.keys():
            dict3[i]=fifty["batsman_runs"]
            dict4[i]=maximum["batsman_runs"][0]
d={"batsman":dict3.keys(),"number of hundreds 2019":dict3.values(),"Highest score":dict4.values()}
hundred_19=pd.DataFrame(d)
    
hundred_19.sort_values(by="Highest score",ascending=False)
# Out:
#           batsman  number of hundreds 2019  Highest score
# 17     J Bairstow                        1            115
# 51      AM Rahane                        1            108
# 53      SV Samson                        1            106
# 47       CH Gayle                        1            105
# 45       KL Rahul                        1            104
# ..            ...                      ...            ...
# 107       J Denly                        0              0
# 100     P Krishna                        0              0
# 96         S Kaul                        0              0
# 84   S Lamichhane                        0              0
# 88      MM Sharma                        0              0
#
# [144 rows x 3 columns]

# %%
dict4={}
dict3={}
batsman=set(df["batsman"])
columns=["id","batsman","batsman_runs"]
ipl1=ipl[columns]
for i in ipl1["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict3:
    batter=ipl1[ipl1["batsman"]==i]
    runs=batter.groupby(["id","batsman"],as_index=False).agg({"batsman_runs":"sum"})
    maximum=runs.groupby(["batsman"],as_index=True).agg({"batsman_runs":'max'})
    for i in runs["batsman"]:
        if i in dict3.keys():
            dict3[i]=maximum["batsman_runs"][0]
# for key, value in dict3.items():
 #     if value in dict3:
#         dict4   [value].append(key)
#     else:
#         dict4[value]=[key]
#         if value in new_dict:
#             new_dict[value].append(key)
#         else:
#             new_dict[value]=[key]
 
#             dict4[i]=maximum["batsman_runs"]
d={"batsman":dict3.keys(),"Highest score":dict3.values()}
highest_score=pd.DataFrame(d)
highest_score.sort_values(by="Highest score",ascending=False)
# dict3
# Out:
#             batsman  Highest score
# 6          CH Gayle            175
# 32      BB McCullum            158
# 71   AB de Villiers            133
# 53          RR Pant            130
# 289         M Vijay            127
# ..              ...            ...
# 245          U Kaul              0
# 399  V Pratap Singh              0
# 377        L Ablish              0
# 392      RR Bhatkal              0
# 295         C Nanda              0
#
# [516 rows x 2 columns]

# %%
batsman=set(df["batsman"])
ids=set(ipl["id"])
dict3={}
dict4={}
columns=["id","batsman","batsman_runs"]
ipl1=ipl[columns]
for i in ipl1["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in ipl1["id"]:
    if i in ids:
        dict4[i]=0
dict4={}
for i in dict3:
    batter=ipl1[ipl1["batsman"]==i]
#     for j in dict4.keys():
#         j=str(j)
    runs=batter.groupby(["id","batsman"],as_index=False).agg({"batsman_runs":"sum"})
#     batsman=runs[runs]
#     print(runs)
    fifty=runs[(runs['batsman_runs']>=50) & (runs['batsman_runs']<100)].count()
#     columns=["batsman","batsman_runs"]
    for i in runs["batsman"]:
        if i in dict3.keys():
            dict3[i]=fifty["batsman_runs"]
dict3
d={"batsman":dict3.keys(),"number of fifties":dict3.values()}
fifties=pd.DataFrame(d)
fifties.sort_values(by="number of fifties",ascending=False)
# Out:
#            batsman  number of fifties
# 0        DA Warner                 44
# 87         V Kohli                 38
# 33        SK Raina                 38
# 1         S Dhawan                 37
# 19       RG Sharma                 36
# ..             ...                ...
# 229  Mohammad Asif                  0
# 228        RR Raje                  0
# 227    YV Takawale                  0
# 226  Misbah-ul-Haq                  0
# 515        S Singh                  0
#
# [516 rows x 2 columns]

# %%
batsman=set(df["batsman"])
ids=set(ipl["id"])
dict3={}
dict4={}
columns=["id","batsman","batsman_runs"]
ipl1=ipl[columns]
for i in ipl1["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in ipl1["id"]:
    if i in ids:
        dict4[i]=0
dict4={}
for i in dict3:
    batter=ipl1[ipl1["batsman"]==i]
#     for j in dict4.keys():
#         j=str(j)
    runs=batter.groupby(["id","batsman"],as_index=False).agg({"batsman_runs":"sum"})
#     batsman=runs[runs]
#     print(runs)
    century=runs[(runs['batsman_runs']>=100)].count()
#     columns=["batsman","batsman_runs"]
    for i in runs["batsman"]:
        if i in dict3.keys():
            dict3[i]=century["batsman_runs"]
dict3
d={"batsman":dict3.keys(),"number of centuries":dict3.values()}
hundreds=pd.DataFrame(d)
hundreds.sort_values(by="number of centuries",ascending=False)
# Out:
#              batsman  number of centuries
# 6           CH Gayle                    7
# 87           V Kohli                    5
# 0          DA Warner                    4
# 10         SR Watson                    4
# 71    AB de Villiers                    3
# ..               ...                  ...
# 183        SB Styris                    0
# 181       VVS Laxman                    0
# 180  Y Venugopal Rao                    0
# 178      LRPL Taylor                    0
# 515          S Singh                    0
#
# [516 rows x 2 columns]

# %%
batsman=set(df["batsman"])
dict2={}
for i in df["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=df[df["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
d={"batsman":dict2.keys(),"total runs":dict2.values()}
batter_df=pd.DataFrame(d)
dict3={}
for i in df["batsman"]:
    if i in batsman:
        dict3[i]=0
for i in dict3:
    batter1=df[df["batsman"]==i]
    sixes=batter1[batter1["batsman_runs"]==6].count()
    dict3[i]=sixes["batsman_runs"]
six={"batsman":dict2.keys(),"Number of sixes":dict3.values()}
six_df=pd.DataFrame(six)
six_df=six_df.sort_values(by="Number of sixes",ascending=False)
six_df
# sns.barplot(x="batsman",y="Number of sixes",data="merged_df")
# Out:
#               batsman  Number of sixes
# 6            CH Gayle              327
# 71     AB de Villiers              214
# 30           MS Dhoni              207
# 33           SK Raina              195
# 19          RG Sharma              194
# ..                ...              ...
# 382          ND Doshi                0
# 383  Y Gnaneswara Rao                0
# 238     CK Kapugedera                0
# 236          A Kumble                0
# 258       VS Yeligati                0
#
# [516 rows x 2 columns]

# %%
plt.figure(figsize=(15,10))
six_df.set_index(six_df["batsman"])
sns.barplot(x="batsman",y="Number of sixes",data=six_df.head(10))
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='Number of sixes'>

# %%
dict4={}
for i in df["batsman"]:
    if i in batsman:
        dict4[i]=0
for i in dict4:
    batter1=df[df["batsman"]==i]
    fours=batter1[batter1["batsman_runs"]==4].count()
    dict4[i]=fours["batsman_runs"]
fours={"batsman":dict2.keys(),"Number of boundaries":dict4.values()}
four_df=pd.DataFrame(fours)
four_df.sort_values(by="Number of boundaries",ascending=False)
# four_df[four_df["batsman"]=="CH Gayle"]
# Out:
#                batsman  Number of boundaries
# 1             S Dhawan                   526
# 33            SK Raina                   495
# 36           G Gambhir                   492
# 87             V Kohli                   482
# 0            DA Warner                   459
# ..                 ...                   ...
# 423          IC Pandey                     0
# 296   Mashrafe Mortaza                     0
# 297            A Singh                     0
# 303  Mohammad Ashraful                     0
# 258        VS Yeligati                     0
#
# [516 rows x 2 columns]

# %%
plt.figure(figsize=(15,10))
# four_df.set_index(four_df["batsman"])
sns.barplot(x="batsman",y="Number of boundaries",data=four_df.head(10))
# Out:
# <AxesSubplot:xlabel='batsman', ylabel='Number of boundaries'>

# %%
dict3={}
batsman=set(df["batsman"])
dismissals=set(df["player_dismissed"])
dismissals.remove(np.nan)
dict2={}
for i in df["batsman"]:
    if i in batsman:
        dict2[i]=0
for i in dict2:
    batter=df[df["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dict2[i]=runs
for i in df["batsman"]:
    if i in batsman:
        dict3[i]=0
dict4={}
count=0
for i in df["player_dismissed"]:
    if i in dismissals:
        dict4[i]=0
for i in df["player_dismissed"]:
    if i in dismissals:
        dict4[i]+=1
# dict4.pop('nan')
for i in dict3:
    batter=df[df["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    balls_faced=batter["ball"].count()
    strike_rate=(runs/balls_faced)*100
    dict3[i]=round(strike_rate,2)
# del dict4[0]
d={"player":dict2.keys(),"total runs":dict2.values(),"strike_rate":dict3.values()}
d1={"got dismissed":dict4.values()}
strikerate=pd.DataFrame(d)
dismissed=pd.DataFrame(d1)
# strikerate=strikerate.sort_values(by="strike_rate",ascending=False)
# strikerate["got dismissed"]=dict4.values()
# strikerate["average"]=strikerate["total runs"]/dismissed["got dismissed"]
# strikerate=strikerate.sort_values(by="strike_rate",ascending=False)
strikerate
# Out:
#            player  total runs  strike_rate
# 0       DA Warner        4741       139.52
# 1        S Dhawan        4632       122.67
# 2    MC Henriques         969       126.01
# 3    Yuvraj Singh        2765       125.28
# 4        DJ Hooda         535       124.13
# ..            ...         ...          ...
# 511      A Turner           4        36.36
# 512        H Brar          22       157.14
# 513  S Rutherford          82       149.09
# 514         P Raj           0         0.00
# 515       S Singh          17        94.44
#
# [516 rows x 3 columns]

# %%
# BOWLERS STRIKE RATE:
bowlers=set(df["bowler"])
dict1={}
dict2={}
dict3={}
dict4={}
dict5={}
dict6={}
wkts=0
columns=["id","bowler","player_dismissed","ball","total_runs"]
ipl1=ipl[columns]
# null=pd.isnull(df["player_dismissed"])
for i in ipl1["bowler"]:
    if i in bowlers:
        dict1[i]=0
        dict5[i]=0
        dict6[i]=0
# df=df.head()
for i in dict1:
    bowler=ipl1[ipl1["bowler"]==i]
    deliveries=bowler["ball"].count()
    overs=deliveries/6
    wkts=bowler["player_dismissed"].count()
    runs_conceded=bowler["total_runs"].sum()
    average=runs_conceded/wkts
    economy=runs_conceded/overs
    wkts1=bowler.groupby(["id","bowler"],as_index=False).agg({"player_dismissed":"count"})
    no_runs=bowler.groupby(["id","bowler","total_runs"],as_index=False).agg({"ball":"count"})
    four_wkts=wkts1[(wkts1["player_dismissed"]==4)].count()
#     five_wkts=wkts1[(wkts1["player_dismissed"]==5)]
    dict1[i]=wkts
    dict2[i]=round(average,2)
    dict3[i]=round(overs,1)
    dict4[i]=round(economy,2)
    for i in wkts1["bowler"]:
        dict5[i]=four_wkts["player_dismissed"]
        dict6[i]=runs_conceded
#     print(no_runs)
# j=dict1[0]
# dict5
D={"bowler":dict1.keys(),"total wickets":dict1.values(),"bowling average":dict2.values(),"number of overs":dict3.values(),"economy":dict4.values(),"4W":dict5.values(),"runs given":dict6.values()}
bowler_average=pd.DataFrame(D)
bowler_average=bowler_average.sort_values(by="total wickets",ascending=False)
bowler_average=bowler_average.set_index("bowling average")
bowler_average.head(40)
# bowler_average[bowler_average["bowler"]=='S Dhawan']
# Out:
# <ipython-input-42-62b3abcf33c4>:25: RuntimeWarning: divide by zero encountered in longlong_scalars
#   average=runs_conceded/wkts
# <ipython-input-42-62b3abcf33c4>:25: RuntimeWarning: divide by zero encountered in longlong_scalars
#   average=runs_conceded/wkts
# <ipython-input-42-62b3abcf33c4>:25: RuntimeWarning: divide by zero encountered in longlong_scalars
#   average=runs_conceded/wkts
# <ipython-input-42-62b3abcf33c4>:25: RuntimeWarning: divide by zero encountered in longlong_scalars
#   average=runs_conceded/wkts
# <ipython-input-42-62b3abcf33c4>:25: RuntimeWarning: divide by zero encountered in longlong_scalars
#   average=runs_conceded/wkts
# <ipython-input-42-62b3abcf33c4>:25: RuntimeWarning: divide by zero encountered in longlong_scalars
#   average=runs_conceded/wkts
# <ipython-input-42-62b3abcf33c4>:25: RuntimeWarning: divide by zero encountered in longlong_scalars
#   average=runs_conceded/wkts
# ...

# %%
plt.figure(figsize=(15,10))
bowler_average=bowler_average.set_index(bowler_average["bowler"]).head(10)
sns.barplot(x="bowler",y="total wickets",data=bowler_average)
# Out:
# <AxesSubplot:xlabel='bowler', ylabel='total wickets'>

# %%
batsman=set(ipl["batsman"])
# ids=set(ipl["id"])
dict3={}
dict4={}
# columns=["id","batsman","batsman_runs","player_dismissed"]
# ipl=ipl[columns]
for i in ipl["batsman"]:
    if i in batsman:
        dict3[i]=0
dict1={}
dict2={}
for i in dict3:
    batter=ipl[ipl["batsman"]==i]
    runs=batter["batsman_runs"].sum()
    dismissal=batter["player_dismissed"].count()
    average=round((runs/dismissal),2)
    innings=batter.groupby(["id","batsman"],as_index=False).agg({"id":"count"})
    innings=innings.reset_index()
    matches_played=innings["id"].count()
    dict3[i]=average
    dict4[i]=dismissal
    dict2[i]=runs
    dict1[i]=matches_played
d={"batsman":dict3.keys(),"runs":dict2.values(),"dismissals":dict4.values(),"player average":dict3.values(),"innings played":dict1.values()}
batsman_average=pd.DataFrame(d)
batsman_average=batsman_average.set_index("player average")
batsman_average
# Out:
# <ipython-input-44-126b3f2488af>:16: RuntimeWarning: divide by zero encountered in longlong_scalars
#   average=round((runs/dismissal),2)
# <ipython-input-44-126b3f2488af>:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   average=round((runs/dismissal),2)
#                      batsman  runs  dismissals  innings played
# player average
# 41.59              DA Warner  4741         114             126
# 33.81               S Dhawan  4632         137             158
# 27.69           MC Henriques   969          35              50
# 25.37           Yuvraj Singh  2765         109             126
# 16.21               DJ Hooda   535          33              45
# ...                      ...   ...         ...             ...
# 1.33                A Turner     4           3               4
# inf                   H Brar    22           0               1
# 16.40           S Rutherford    82           5               7
# ...

# %%
batsman=set(df["batsman"])
bowler=set(df["bowler"])
dict1={}
# for i in batsman_average["batsman"]:
#     if i in bowler:
#         dict1[i]=0
# for i in bowler_average["bowler"]:
#     if i in batsman:
#         dict2[i]=0
# for i in dict1:
#     batsman=batsman_average[batsman_average["batsman"]==i]
#     batting_avg=batsman["player average"]
#     dict1[i]=batting_avg
# for i in dict2:
#     bowling_avg=bowler_average[bowler_average["bowler"]==i]
#     dict2[i]=bowling_avg
# dict2
# dict1
#  runs=batter.groupby(["id","batsman"],as_index=False).agg({"batsman_runs":"sum"})
#     maximum=runs.groupby(["batsman"],as_index=True).agg({"batsman_runs":'max'})
#     for i in runs["batsman"]:
#         if i in dict3.keys():
#             dict3[i]=maximum["batsman_runs"][0]
all_rounders=batsman.intersection(bowler)
for i in all_rounders:
    dict1[i]=0
for i in all_rounders:
    dict2[i]=0
dict2={}
for i in dict1:
    player=batsman_average[batsman_average["batsman"]==i]
    batting_avg=player.index
    bowler=bowler_average[bowler_average["bowler"]==i]
    bowling_avg=bowler.index
    dict1[i]=batting_avg
    dict2[i]=bowling_avg
values1=[]
values2=[]
items1 = dict1.values()
items2 = dict2.values()
for item in items1:
    i=0
    values1.append(item[i])
    i+=1
for item in items2:
    i=0
    values2.append(item[i])
    i+=1
d={"player":dict1.keys(),"batting average":values1,"bowling average":values2}
allrounder=pd.DataFrame(d)
# allrounder=allrounder[(allrounder["batting average"]>=20) & (allrounder["batting average"]!='inf') &(allrounder["bowling average"]<30) &(allrounder["bowling average"]!="inf")]
allrounder
# allrounder["batting average"]=allrounder.where((allrounder["batting average"]!="inf"))
# allrounder["bowling average"]=allrounder.where((allrounder["bowling average"]!="inf"))
# allrounder.sort_values(by=["batting average","bowling average"],ascending=False).head(40)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-d47b10b4f6cb> in <module>
#      45 for item in items2:
#      46     i=0
# ---> 47     values2.append(item[i])
#      48     i+=1
#      49 d={"player":dict1.keys(),"batting average":values1,"bowling average":values2}
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4099         if is_scalar(key):
#    4100             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4101             return getitem(key)
#    4102
#    4103         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
batsman_only=batsman_average.reset_index()
# batsman_average[batsman_average["player average"]>=30.00]
batsman_only=batsman_only[~(batsman_only["player average"]==float("inf"))]
batsman_only.sort_values(by="player average",ascending=False)

# %%
# batsman selection
batter=set(batsman_only["batsman"])
dict={}
dict1={}
dict2={}
dict3={}
dict4={}
dict5={}
dict6={}
dict7={}
for i in batter:
    dict[i]=0
    dict1[i]=0
    dict2[i]=0
    dict3[i]=0
    dict4[i]=0
    dict5[i]=0
    dict6[i]=0
    dict7[i]=0
list1=[]
average1=batsman_only.set_index("batsman")
for i in batter:
    list1.append(i)
rows1=list1
col1=["runs","player average"]
select_batter=average1.loc[rows1,col1]
for i in list1:
    sixes=six_df[six_df["batsman"]==i]
    fours=four_df[four_df["batsman"]==i]
    fifty=fifties[fifties["batsman"]==i]
    century=hundreds[hundreds["batsman"]==i]
    strikerate1=strikerate[strikerate["player"]==i]
    maximum=highest_score[highest_score["batsman"]==i]
    innings_played=batsman_only[batsman_only["batsman"]==i]
    dict1[i]=int(sixes["Number of sixes"])
    dict2[i]=int(fours["Number of boundaries"])
    dict3[i]=int(fifty["number of fifties"])
    dict4[i]=int(century["number of centuries"])
    dict5[i]=float(round(strikerate1["strike_rate"],2))
    dict6[i]=int(maximum["Highest score"])
    dict7[i]=int(innings_played["innings played"])
select_batter["6's"]=dict1.values()
select_batter["4's"]=dict2.values()
select_batter["50's"]=dict3.values()
select_batter["100's"]=dict4.values()
select_batter["strike rate"]=dict5.values()
select_batter["high score"]=dict6.values()
select_batter["innings played"]=dict7.values()   

select_batter=select_batter[~(select_batter["player average"]==float("inf"))]
select_batter.sort_values(by="100's",ascending=False)
select_batter=select_batter.reset_index()
select_batter["boundary percentage"]=round(((select_batter["4's"]*4 + select_batter["6's"]*6)/select_batter["runs"])*100,2)
select_batter=select_batter[select_batter["innings played"]>30]
select_batter.sort_values(by="boundary percentage",ascending=False)
# select_batter[select_batter["strike rate"]>=140]
# Classifying batsman into openers and middle order batsman
openers=select_batter[(select_batter["strike rate"]>=120) & (select_batter["strike rate"]<=130) & (select_batter["boundary percentage"]>=50.0) & (select_batter["player average"]>=30)  & (select_batter["player average"]<=40)]
# openers
middle1=select_batter[(select_batter["strike rate"]>=130) & (select_batter["strike rate"]<=140)& (select_batter["boundary percentage"]>=40.0)]
# middle2=select_batter[(select_batter["player average"]>=50) & (select_batter["strike rate"]>=140) & (select_batter["boundary percentage"]>=50.0)]
middle1
select_batter

# %%
select_batter["round avg"]=round(select_batter["player average"]/10)*10
select_batter["round avg"].value_counts(ascending=True)
select_batter["round sr"]=round(select_batter["strike rate"]/10)*10
select_batter["round sr"].value_counts(ascending=True)
select_batter["round avg"].value_counts(ascending=True) 
select_batter["round bp"]=round(select_batter["boundary percentage"]/10)*10
select_batter["round bp"].value_counts(ascending=True)

# %%
# Selecting a opening batsman
opening_batter=[]
openers=select_batter[(select_batter["round avg"]>=25) & (select_batter["round avg"]<=30) & (select_batter["round sr"]>=120) & (select_batter["round sr"]<=130) &  (select_batter["boundary percentage"]>=40.00)]
openers=openers[(openers["50's"]>10) & (openers["strike rate"]>=125)]
mean_avg=np.mean(openers["player average"])
mean_sr=np.mean(openers["strike rate"])
# 128.51 mean
# no2=openers[(openers["runs"]>2000) & (openers["innings played"]<=100)]
openers=openers[(openers["strike rate"]>mean_sr) & (openers["player average"]>mean_avg)]
openers=openers.sort_values(by="runs",ascending=False).head(4)
for i in openers["batsman"]:
    opening_batter.append(i)
openers

# %%
upper_middle=[]
lower_middle=[]
mean_bp=round(np.mean(select_batter["boundary percentage"]),0)
middle_order=select_batter[(select_batter["round avg"]>=30) & (select_batter["round sr"]>=130) & (select_batter["round sr"]<=140) &  (select_batter["boundary percentage"]>=40.00)]
low_bp=round(np.min(middle_order["boundary percentage"]),0)
avg_bp=round(np.mean(middle_order["boundary percentage"]),2)
low_sr=round(np.min(middle_order["strike rate"]),0)
avg_sr=round(np.mean(middle_order["strike rate"]),0)
pos_3_4=middle_order[(middle_order["boundary percentage"]>=low_bp) & (middle_order["boundary percentage"]<=avg_bp) & (middle_order["strike rate"]>=low_sr) &(middle_order["strike rate"]<=avg_sr)]
for i in pos_3_4["batsman"]:
    if i in opening_batter:
        pos_3_4=pos_3_4[pos_3_4["batsman"]!=i]
avg_sr1=round(np.mean(pos_3_4["player average"]),0)
pos_3_4=pos_3_4[pos_3_4["player average"]>=avg_sr1]
pos_3_4=pos_3_4.sort_values(by=["innings played"],ascending=False).head(2)
for i in pos_3_4["batsman"]:
    upper_middle.append(i)
upper_middle

# %%
# Selecting player for position 5 and also giving more weightage to being a wicket keeper
lower_order=[]
mean_bp=round(np.mean(select_batter["boundary percentage"]),0)
middle_order=select_batter[(select_batter["round avg"]>=30) & (select_batter["round sr"]>=130) & (select_batter["round sr"]<=140) &  (select_batter["boundary percentage"]>=40.00)]
high_bp=round(np.max(middle_order["boundary percentage"]),0)
avg_bp=round(np.mean(middle_order["boundary percentage"]),0)
high_sr=round(np.max(middle_order["strike rate"]),0)
avg_sr=round(np.mean(middle_order["strike rate"]),0)
mode_bp=middle_order["boundary percentage"].mode()
med_50=middle_order["50's"].median()
pos_5=middle_order[(middle_order["strike rate"]>=avg_sr) &(middle_order["boundary percentage"]>=low_bp)&(middle_order["boundary percentage"]<=avg_bp)&(middle_order["50's"]>=med_50)]
# pos_5_6["boundary percentage"].mean()
temp_5=middle_order[(middle_order["strike rate"]>=140)&(middle_order["50's"]>=med_50)]
for i in pos_5["batsman"]:
    if i in opening_batter or i in upper_middle:
        pos_5=pos_5[pos_5["batsman"]!=i]
pos_5=pos_5.sort_values(by="innings played",ascending=False).head(1)
pos_5
lower_order.append("MS Dhoni")
lower_order

# %%
select_bowler=bowler_average.reset_index()
# select_bowler=select_bowler[select_bowler["bowling average"]<=30.00]
# select_bowler[select_bowler["bowler"]=="SL Malinga"]
select_bowler.sort_values(by="total wickets",ascending=False)
select_bowler

# %%
# allrounder selection
df1=allrounder
df1=df1[~(df1["bowling average"]==float("inf"))]
df1=df1[~(df1["batting average"]==float("inf"))]
# df1=df1[~(df1['batting average']==float("inf"))]
# df1=df1.sort_values(by="batting average",ascending=False)
# strikerate_df=strikerate
set1=set(strikerate["player"])
batnbowl=set(df1["player"])
dict={}
dict1={}
dict2={}
dict3={}
dict4={}
dict5={}
dict6={}
dict7={}
dict8={}
dict9={}
dict10={}
for i in batnbowl:
    dict[i]=0
    dict1[i]=0
    dict2[i]=0
    dict3[i]=0
    dict4[i]=0
    dict5[i]=0
    dict6[i]=0
    dict7[i]=0
for i in batnbowl:
    sixes=six_df[six_df["batsman"]==i]
    fours=four_df[four_df["batsman"]==i]
    fifty=fifties[fifties["batsman"]==i]
    strikerate1=strikerate[strikerate["player"]==i]
    maximum=highest_score[highest_score["batsman"]==i]
    bowler=select_bowler[select_bowler["bowler"]==i]
    dict[i]=int(sixes["Number of sixes"])
    dict1[i]=int(fours["Number of boundaries"])
    dict2[i]=int(fifty["number of fifties"])
    dict3[i]=float(round(strikerate1["strike_rate"],2))
    dict4[i]=int(maximum["Highest score"])
    dict5[i]=bowler["total wickets"]
    dict6[i]=bowler["bowling average"]
    dict7[i]=bowler["runs given"]
    dict8[i]=bowler["economy"]
    dict9[i]=bowler["4W"]
    dict10[i]=bowler["number of overs"]
#     print(dict7)
# print(dict2)
# values1=[]
# values2=[]
items1 = dict2.values()
# dict2.values()
# items2 = dict3.values()
# for item in items1:
#     i=0
#     values1.append(item[i])
#     i+=1
# for item in items2:
#     i=0
#     values2.append(item[i])
#     i+=1
# print(dict1)
d={"player":dict.keys(),"6's":dict.values(),"4's":dict1.values(),"fifties":dict2.values(),"strikerate":dict3.values(),"high score":dict4.values(),"number of overs":dict10.values(),"total wickets":dict5.values(),"bowling average":dict6.values(),"runs conceded":dict7.values(),"economy":dict8.values(),"4W":dict9.values()}
allrounders=pd.DataFrame(d)
allrounders
# allrounders
# list1
# values1

# %%
perform08=df1[df1["season"]==2008]
winners08=perform08["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2010")
winners08
plt.figure(figsize=(20,10))
plt.bar(winners08.keys(),winners08,color="maroon")

# %%
perform09=df1[df1["season"]==2009]
winners09=perform09["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2010")
winners09
plt.figure(figsize=(20,10))
plt.bar(winners09.keys(),winners09,color="maroon")

# %%
perform10=df1[df1["season"]==2010]
winners10=perform10["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2010")
winners10
plt.figure(figsize=(20,10))
plt.bar(winners10.keys(),winners10,color="maroon")

# %%
perform12=df1[df1["season"]==2011]
winners11=perform12["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2010")
winners11
plt.figure(figsize=(30,10))
plt.bar(winners11.keys(),winners11,color="maroon")

# %%
perform12=df1[df1["season"]==2012]
winners12=perform12["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2012")
winners12
plt.figure(figsize=(20,10))
plt.bar(winners12.keys(),winners12.values,color="maroon")

# %%
perform13=df1[df1["season"]==2013]
winners13=perform13["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2013")
winners13
plt.figure(figsize=(20,10))
plt.bar(winners13.keys(),winners13.values,color="maroon")

# %%
perform14=df1[df1["season"]==2014]
winners14=perform14["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2014")
winners14
plt.figure(figsize=(20,10))
plt.bar(winners14.keys(),winners14.values,color="maroon")

# %%
perform15=df1[df1["season"]==2015]
winners15=perform15["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2015")
winners15
plt.figure(figsize=(20,10))
plt.bar(winners15.keys(),winners15.values,color="maroon")

# %%
perform16=df1[df1["season"]==2016]
winners16=perform16["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2016")
winners16
plt.figure(figsize=(20,10))
plt.bar(winners16.keys(),winners16.values,color="maroon")

# %%
perform17=df1[df1["season"]==2017]
winners17=perform17["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2017")
# winners09
plt.figure(figsize=(20,10))
plt.bar(winners17.keys(),winners17.values,color="maroon")

# %%
perform18=df1[df1["season"]==2018]
winners18=perform18["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2009")
winners18
plt.figure(figsize=(20,10))
plt.bar(winners18.keys(),winners18.values,color="maroon")

# %%
perform19=df1[df1["season"]==2019]
winners19=perform19["winner"].value_counts(ascending=False)
print("no of matches won by each team in 2019")
winners19
plt.figure(figsize=(20,10))
plt.bar(winners19.keys(),winners19.values,color="maroon")

# %%
# most_wins=ipl_08[ipl_08[""]]
ipl_08=ipl_08[ipl_08["winner"]=="Royal Challengers Bangalore"]
# plt.figure(figsize=(30,10))
sns.countplot(x="winner",hue="winner",data=ipl_08)

# %%
warne=ipl_08[ipl_08["bowler"]=="Shane Warne"]

# %%
# ipl_08=ipl_08["batsman_runs"].fillna(0)
kohli_08=ipl_08[ipl_08["batsman"]=="V Kohli"]
kohli_runs= kohli_08['batsman_runs'].sum()
balls_faced=kohli_08['ball'].count()
sr08= (kohli_runs/balls_faced)
sr08=float("%.2f"%sr08)*100
sr08

# %%
kohli_09=ipl_09[ipl_09["batsman"]=="V Kohli"]
kohli_runs= kohli_09['batsman_runs'].sum()
balls_faced=kohli_09['ball'].count()
sr09=(kohli_runs/balls_faced)
sr09=float("%.2f"%sr09)*100
sr09

# %%
kohli_10=ipl_10[ipl_10["batsman"]=="V Kohli"]
kohli_runs= kohli_10['batsman_runs'].sum()
balls_faced=kohli_10['ball'].count()
sr10= (kohli_runs/balls_faced)*100
sr10=float("%.2f"%sr10)
sr10

# %%
kohli_11=ipl_11[ipl_11["batsman"]=="V Kohli"]
kohli_runs= kohli_11['batsman_runs'].sum()
balls_faced=kohli_11['ball'].count()
sr11= (kohli_runs/balls_faced)*100
sr11=float("%.2f"%sr11)
balls_faced

# %%
kohli_12=ipl_12[ipl_12["batsman"]=="V Kohli"]
kohli_runs= kohli_12['batsman_runs'].sum()
balls_faced=kohli_12['ball'].count()
sr12= (kohli_runs/balls_faced)*100
sr12=float("%.2f"%sr12)
sr12

# %%
kohli_13=ipl_13[ipl_13["batsman"]=="V Kohli"]
kohli_runs= kohli_13['batsman_runs'].sum()
balls_faced=kohli_13['ball'].count()
sr13= (kohli_runs/balls_faced)*100
sr13=float("%.2f"%sr13)
balls_faced

# %%
kohli_14=ipl_14[ipl_14["batsman"]=="V Kohli"]
kohli_runs= kohli_14['batsman_runs'].sum()
balls_faced=kohli_14['ball'].count()
sr14= (kohli_runs/balls_faced)*100
sr14=float("%.2f"%sr14)
balls_faced

# %%
kohli_15=ipl_15[ipl_15["batsman"]=="V Kohli"]
kohli_runs= kohli_15['batsman_runs'].sum()
balls_faced=kohli_15['ball'].count()
sr15= (kohli_runs/balls_faced)*100
sr15=float("%.2f"%sr15)
balls_faced

# %%
kohli_16=ipl_16[ipl_16["batsman"]=="V Kohli"]
kohli_runs16=kohli_16["batsman_runs"].sum()
balls_faced=kohli_16['ball'].count()
sr16= (kohli_runs16/balls_faced)*100
sr16=float("%.2f"%sr16)
sr16

# %%
kohli_17=ipl_17[ipl_17["batsman"]=="V Kohli"]
kohli_runs17=kohli_17['batsman_runs'].sum()

balls_faced=kohli_17['ball'].count()
sr17= (kohli_runs17/balls_faced)*100
sr17=float("%.2f"%sr17)
sr17
# print("%.2f"%sr17)

# %%
kohli_18=ipl_18[ipl_18["batsman"]=="V Kohli"]
kohli_runs18=kohli_18['batsman_runs'].sum()


balls_faced=kohli_18['ball'].count()
sr18= (kohli_runs18/balls_faced)*100
sr18=float("%.2f"%sr18)
sr18
# print("%.2f"%sr18)

# %%
kohli_19=ipl_19[ipl_19["batsman"]=="V Kohli"]
kohli_runs19= kohli_19['batsman_runs'].sum()
balls_faced=kohli_19['ball'].count()
sr19= (kohli_runs19/balls_faced)*100
sr19=float("%.2f"%sr19)
print("%.2f"%sr19)

# %%
dict1={'2008':sr08,'2009':sr09,'2010':sr10,'2011':sr11,'2012':sr12,'2013':sr13,'2014':sr14,'2015':sr15,'2016':sr16,'2017':sr17,'2018':sr18,'2019':sr19}
season=list(dict1.keys()) 
runs=list(dict1.values())
plt.figure(figsize=(10,5))
plt.bar(season,runs,width=0.4,color="violet")
plt.xlabel("Seasons")
plt.ylabel("Strike rate")
plt.title("Virat Kohli's strike rate from 2008-present")
